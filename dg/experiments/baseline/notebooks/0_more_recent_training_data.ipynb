# %%
import os
import joblib
import pickle

import pandas as pd
import numpy as np

from utils_visualize import (
    get_result_table,
    plot_heatmap
)

pd.options.display.max_rows = 100

# %%
artifacts_fpath = '/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/dg/experiments/baseline/artifacts'

# %% [markdown]
# #### Setup table and figure parameters

# %%
y_axis = {
    'auc':{
        'lim':[-0.1, 0],
        'lim_raw':[0.75,.85],
        'label':'AUROC'
    },
    'auprc':{
        'lim':[-0.15, 0],
        'lim_raw':[.15,.35],
        'label':'AUPRC'
    },
    'ace_abs_logistic_logit':{
        'lim':[0, 0.10],
        'lim_raw':[0,0.05],
        'label':'Calibration'
    },
    'loss_bce':{
        'lim':[0, 0.4],
        'label':'BCE Loss'
    }
}

metrics = {
    'auc':'AUROC',
    'auprc':'AUPRC',
    'ace_abs_logistic_logit':'Calibration',
}

tasks = {
    'hospital_mortality':'In-Hospital Mortality',
    'LOS_7':'LOS > 7 Days',
    'readmission_30':'Readmission in 30 Days',
    'icu_admission':'Admission to ICU'
}

train_years = {
    '2009_2010_2011_2012':'09-12',
    '2010_2011_2012_2013':'10-13',
    '2011_2012_2013_2014':'11-14',
    '2012_2013_2014_2015':'12-15',
    '2013_2014_2015_2016':'13-16',
    '2014_2015_2016_2017':'14-17',
    '2015_2016_2017_2018':'15-18',
    '2016_2017_2018_2019':'16-19',
    '2017_2018_2019_2020':'17-20',
    '2018_2019_2020_2021':'18-21',
}

# %% [markdown]
# #### ID Performance

# %%
df = get_result_table(artifacts_fpath,train_years,tasks,metrics)
print("ID Performance of Models Trained on Various Year Groups")
display(df)
# Out:
# ID Performance of Models Trained on Various Year Groups
# Train Group                                        09-12  \
# Task                   Metric
# In-Hospital Mortality  AUROC         0.819 (0.79, 0.844)
#                        AUPRC        0.096 (0.074, 0.123)
#                        Calibration  0.005 (0.003, 0.008)
# LOS > 7 Days           AUROC         0.753 (0.74, 0.765)
#                        AUPRC         0.45 (0.424, 0.473)
#                        Calibration  0.008 (0.003, 0.015)
# Readmission in 30 Days AUROC        0.768 (0.748, 0.788)
#                        AUPRC        0.258 (0.223, 0.299)
#                        Calibration  0.007 (0.003, 0.011)
# Admission to ICU       AUROC        0.841 (0.822, 0.857)
#                        AUPRC        0.379 (0.333, 0.426)
#                        Calibration   0.005 (0.002, 0.01)
#
# Train Group                                        10-13  \
# Task                   Metric
# In-Hospital Mortality  AUROC        0.828 (0.804, 0.849)
#                        AUPRC         0.11 (0.089, 0.135)
#                        Calibration  0.003 (0.002, 0.005)
# LOS > 7 Days           AUROC        0.755 (0.743, 0.768)
#                        AUPRC        0.451 (0.426, 0.475)
#                        Calibration  0.009 (0.004, 0.015)
# Readmission in 30 Days AUROC        0.766 (0.744, 0.788)
#                        AUPRC        0.251 (0.218, 0.293)
#                        Calibration   0.005 (0.002, 0.01)
# Admission to ICU       AUROC        0.835 (0.818, 0.852)
#                        AUPRC        0.396 (0.353, 0.437)
#                        Calibration  0.006 (0.002, 0.011)
#
# Train Group                                        11-14  \
# Task                   Metric
# In-Hospital Mortality  AUROC         0.814 (0.79, 0.838)
#                        AUPRC        0.098 (0.076, 0.124)
#                        Calibration  0.005 (0.002, 0.007)
# LOS > 7 Days           AUROC         0.771 (0.76, 0.783)
#                        AUPRC        0.459 (0.438, 0.485)
#                        Calibration  0.007 (0.003, 0.014)
# Readmission in 30 Days AUROC         0.757 (0.734, 0.78)
#                        AUPRC        0.239 (0.203, 0.279)
#                        Calibration  0.006 (0.002, 0.009)
# Admission to ICU       AUROC        0.842 (0.826, 0.858)
#                        AUPRC        0.401 (0.358, 0.443)
#                        Calibration  0.008 (0.004, 0.013)
#
# Train Group                                        12-15  \
# Task                   Metric
# In-Hospital Mortality  AUROC        0.811 (0.786, 0.833)
#                        AUPRC        0.094 (0.072, 0.123)
#                        Calibration  0.004 (0.002, 0.006)
# LOS > 7 Days           AUROC        0.781 (0.769, 0.792)
#                        AUPRC        0.452 (0.429, 0.474)
#                        Calibration  0.006 (0.003, 0.011)
# Readmission in 30 Days AUROC        0.778 (0.756, 0.799)
#                        AUPRC        0.242 (0.204, 0.279)
#                        Calibration  0.004 (0.002, 0.008)
# Admission to ICU       AUROC        0.842 (0.825, 0.859)
#                        AUPRC        0.389 (0.351, 0.429)
#                        Calibration  0.009 (0.005, 0.013)
#
# Train Group                                        13-16  \
# Task                   Metric
# In-Hospital Mortality  AUROC        0.831 (0.808, 0.851)
#                        AUPRC          0.109 (0.08, 0.14)
#                        Calibration  0.005 (0.004, 0.007)
# LOS > 7 Days           AUROC           0.79 (0.779, 0.8)
#                        AUPRC         0.457 (0.434, 0.48)
#                        Calibration  0.006 (0.002, 0.011)
# Readmission in 30 Days AUROC        0.783 (0.762, 0.803)
#                        AUPRC          0.225 (0.19, 0.26)
#                        Calibration  0.005 (0.002, 0.008)
# Admission to ICU       AUROC        0.859 (0.844, 0.873)
#                        AUPRC        0.415 (0.377, 0.454)
#                        Calibration  0.004 (0.001, 0.008)
#
# Train Group                                        14-17  \
# Task                   Metric
# In-Hospital Mortality  AUROC        0.833 (0.811, 0.853)
#                        AUPRC        0.104 (0.079, 0.133)
#                        Calibration  0.003 (0.001, 0.004)
# LOS > 7 Days           AUROC        0.798 (0.787, 0.807)
#                        AUPRC        0.455 (0.433, 0.478)
#                        Calibration   0.01 (0.005, 0.015)
# Readmission in 30 Days AUROC        0.798 (0.779, 0.815)
#                        AUPRC        0.237 (0.204, 0.276)
#                        Calibration  0.005 (0.002, 0.008)
# Admission to ICU       AUROC         0.873 (0.86, 0.885)
#                        AUPRC        0.428 (0.385, 0.465)
#                        Calibration  0.003 (0.001, 0.006)
#
# Train Group                                        15-18  \
# Task                   Metric
# In-Hospital Mortality  AUROC        0.839 (0.817, 0.861)
#                        AUPRC        0.126 (0.096, 0.161)
#                        Calibration  0.003 (0.002, 0.005)
# LOS > 7 Days           AUROC         0.801 (0.791, 0.81)
#                        AUPRC        0.474 (0.453, 0.497)
#                        Calibration  0.005 (0.002, 0.009)
# Readmission in 30 Days AUROC        0.802 (0.785, 0.818)
#                        AUPRC        0.248 (0.213, 0.287)
#                        Calibration  0.003 (0.002, 0.006)
# Admission to ICU       AUROC        0.874 (0.863, 0.885)
#                        AUPRC        0.404 (0.368, 0.438)
#                        Calibration  0.002 (0.001, 0.005)
#
# Train Group                                        16-19  \
# Task                   Metric
# In-Hospital Mortality  AUROC        0.845 (0.824, 0.866)
#                        AUPRC        0.128 (0.101, 0.161)
#                        Calibration  0.004 (0.002, 0.006)
# LOS > 7 Days           AUROC        0.799 (0.789, 0.808)
#                        AUPRC        0.476 (0.456, 0.496)
#                        Calibration   0.006 (0.003, 0.01)
# Readmission in 30 Days AUROC        0.793 (0.774, 0.811)
#                        AUPRC        0.268 (0.235, 0.305)
#                        Calibration  0.004 (0.002, 0.007)
# Admission to ICU       AUROC        0.869 (0.859, 0.881)
#                        AUPRC         0.41 (0.376, 0.447)
#                        Calibration  0.004 (0.001, 0.007)
#
# Train Group                                        17-20                 18-21
# Task                   Metric
# In-Hospital Mortality  AUROC         0.85 (0.829, 0.868)  0.839 (0.819, 0.862)
#                        AUPRC         0.12 (0.094, 0.155)  0.113 (0.088, 0.143)
#                        Calibration  0.003 (0.002, 0.005)  0.004 (0.003, 0.006)
# LOS > 7 Days           AUROC        0.796 (0.787, 0.804)    0.79 (0.78, 0.799)
#                        AUPRC        0.468 (0.449, 0.487)  0.464 (0.445, 0.484)
#                        Calibration  0.007 (0.004, 0.011)  0.008 (0.005, 0.013)
# Readmission in 30 Days AUROC         0.794 (0.777, 0.81)  0.785 (0.767, 0.803)
#                        AUPRC        0.254 (0.223, 0.287)  0.244 (0.213, 0.277)
#                        Calibration  0.003 (0.001, 0.005)  0.003 (0.001, 0.006)
# Admission to ICU       AUROC        0.882 (0.874, 0.891)  0.877 (0.868, 0.886)
#                        AUPRC          0.49 (0.463, 0.52)  0.492 (0.462, 0.518)
#                        Calibration  0.008 (0.005, 0.011)  0.011 (0.007, 0.014)

# %% [markdown]
# #### Heatmap

# %%
tasks = {
    'LOS_7':'LOS > 7 Days',
    'icu_admission':'Admission to ICU'
}

train_years = {
    '2013':'13-13',
    '2014':'14-14',
    '2015':'15-15',
    '2016':'16-16',
    '2017':'17-17',
    '2018':'18-18',
    '2019':'19-19',
    '2020':'20-20',
    '2021':'21-21',
    '2010_2011_2012_2013':'10-13',
    '2011_2012_2013_2014':'11-14',
    '2012_2013_2014_2015':'12-15',
    '2013_2014_2015_2016':'13-16',
    '2014_2015_2016_2017':'14-17',
    '2015_2016_2017_2018':'15-18',
    '2016_2017_2018_2019':'16-19',
    '2017_2018_2019_2020':'17-20',
    '2018_2019_2020_2021':'18-21',
}

plot_heatmap(
    artifacts_fpath=artifacts_fpath,
    train_years=train_years,
    tasks=tasks,
    dv='comparator',
    y_axis='auto',
    test_group=['2013','2014','2015','2016','2017','2018','2019','2020','2021'],
    figsize=(18,4)
)
