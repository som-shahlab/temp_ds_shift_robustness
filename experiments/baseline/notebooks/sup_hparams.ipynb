# %%
import os
import yaml

import numpy as np
import pandas as pd

pd.options.display.max_rows = 100

# %%
artifacts_fpath = "/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/experiments/baseline/artifacts"
hparams_fpath = "/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/experiments/baseline/hyperparams/nn.yml"
tasks = {
    'hospital_mortality':'In-Hospital Mortality',
    'LOS_7':'LOS > 7 Days',
    'readmission_30':'Readmission in 30 Days',
    'icu_admission':'ICU Admission'
}
years = {
    '2009_2010_2011_2012':'09-12',
    '2013':'2013',
    '2014':'2014',
    '2015':'2015',
    '2016':'2016',
    '2017':'2017',
    '2018':'2018',
    '2019':'2019',
    '2020':'2020',
    '2021':'2021',
    '2009_2010_2011_2012':'09-12',
    '2010_2011_2012_2013':'10-13',
    '2011_2012_2013_2014':'11-14',
    '2012_2013_2014_2015':'12-15',
    '2013_2014_2015_2016':'13-16',
    '2014_2015_2016_2017':'14-17',
    '2015_2016_2017_2018':'15-18',
    '2009_2010_2011_2012':'09-12',
    '2009_2010_2011_2012_2013':'09-13',
    '2009_2010_2011_2012_2013_2014':'09-14',
    '2009_2010_2011_2012_2013_2014_2015':'09-15',
    '2009_2010_2011_2012_2013_2014_2015_2016':'09-16',
    '2009_2010_2011_2012_2013_2014_2015_2016_2017':'09-17',
    '2009_2010_2011_2012_2013_2014_2015_2016_2017_2018':'09-18',
}

# %% [markdown]
# #### Hparam Grid

# %%
hparams = yaml.load(
    open(f"{hparams_fpath}"),
    Loader=yaml.FullLoader
)
df_hparams = pd.DataFrame({
    k:[','.join([str(x) for x in v])] for k,v in hparams.items()
})
df_hparams = df_hparams.T
df_hparams.columns = ['Values']

# %%
df_hparams
# Out:
#                                     Values
# drop_prob                0.0,0.25,0.5,0.75
# early_stopping                        True
# early_stopping_patience                 10
# hidden_dim                         128,256
# lr                            0.0001,1e-05
# num_epochs                             150
# num_hidden                             1,3
# verbose                              False
# sparse_mode                           list

# %% [markdown]
# #### Selected hparams

# %%
df_hparams = pd.DataFrame()

for task in tasks:
    for year in years:
    
        fpath = os.path.join(
            artifacts_fpath,
            task,
            f"models/nn_{year}"
        )

        best_model_name = [x for x in os.listdir(fpath) if "best_model" in x][0]

        hparams = yaml.load(
            open(f"{fpath}/{best_model_name}/hparams.yml"),
            Loader=yaml.FullLoader
        )

        df_hparams = pd.concat((
            df_hparams,
            pd.DataFrame({k:[v] for k,v in hparams.items()}).assign(
                Task=tasks[task],
                Train_Group=years[year]
            )
        ))
df_params = df_hparams[['Task','Train_Group','hidden_dim','num_hidden','lr','drop_prob']]

# %%
df_params.query("Train_Group=='09-12'")
# Out:
#                      Task Train_Group  hidden_dim  num_hidden       lr  \
# 0   In-Hospital Mortality       09-12         128           3  0.00010
# 0            LOS > 7 Days       09-12         128           1  0.00010
# 0  Readmission in 30 Days       09-12         256           3  0.00001
# 0           ICU Admission       09-12         256           1  0.00001
#
#    drop_prob
# 0       0.75
# 0       0.75
# 0       0.50
# 0       0.00

# %%
df_params
# Out:
#                      Task Train_Group  hidden_dim  num_hidden       lr  \
# 0   In-Hospital Mortality       09-12         128           3  0.00010
# 0   In-Hospital Mortality        2013         256           3  0.00010
# 0   In-Hospital Mortality        2014         256           3  0.00010
# 0   In-Hospital Mortality        2015         256           3  0.00010
# 0   In-Hospital Mortality        2016         256           3  0.00010
# 0   In-Hospital Mortality        2017         256           3  0.00010
# 0   In-Hospital Mortality        2018         256           3  0.00010
# 0   In-Hospital Mortality        2019         256           3  0.00010
# 0   In-Hospital Mortality        2020         256           3  0.00010
# 0   In-Hospital Mortality        2021         256           3  0.00010
# 0   In-Hospital Mortality       10-13         128           3  0.00010
# 0   In-Hospital Mortality       11-14         256           3  0.00010
# 0   In-Hospital Mortality       12-15         256           3  0.00001
# 0   In-Hospital Mortality       13-16         128           3  0.00010
# 0   In-Hospital Mortality       14-17         128           3  0.00010
# 0   In-Hospital Mortality       15-18         128           3  0.00010
# 0   In-Hospital Mortality       09-13         128           3  0.00010
# 0   In-Hospital Mortality       09-14         128           3  0.00010
# 0   In-Hospital Mortality       09-15         128           3  0.00010
# 0   In-Hospital Mortality       09-16         128           3  0.00010
# 0   In-Hospital Mortality       09-17         128           3  0.00010
# 0   In-Hospital Mortality       09-18         128           3  0.00010
# 0            LOS > 7 Days       09-12         128           1  0.00010
# 0            LOS > 7 Days        2013         256           1  0.00001
# 0            LOS > 7 Days        2014         256           3  0.00001
# 0            LOS > 7 Days        2015         256           3  0.00001
# 0            LOS > 7 Days        2016         256           1  0.00001
# 0            LOS > 7 Days        2017         128           3  0.00010
# 0            LOS > 7 Days        2018         256           1  0.00001
# 0            LOS > 7 Days        2019         256           3  0.00001
# 0            LOS > 7 Days        2020         256           1  0.00001
# 0            LOS > 7 Days        2021         128           3  0.00001
# 0            LOS > 7 Days       10-13         128           1  0.00010
# 0            LOS > 7 Days       11-14         128           1  0.00001
# 0            LOS > 7 Days       12-15         256           1  0.00001
# 0            LOS > 7 Days       13-16         256           1  0.00001
# 0            LOS > 7 Days       14-17         256           1  0.00001
# 0            LOS > 7 Days       15-18         256           1  0.00001
# 0            LOS > 7 Days       09-13         256           1  0.00001
# 0            LOS > 7 Days       09-14         128           1  0.00010
# 0            LOS > 7 Days       09-15         256           1  0.00010
# 0            LOS > 7 Days       09-16         128           1  0.00010
# 0            LOS > 7 Days       09-17         128           1  0.00010
# 0            LOS > 7 Days       09-18         128           1  0.00010
# 0  Readmission in 30 Days       09-12         256           3  0.00001
# 0  Readmission in 30 Days        2013         256           3  0.00010
# 0  Readmission in 30 Days        2014         128           3  0.00010
# 0  Readmission in 30 Days        2015         256           3  0.00001
# 0  Readmission in 30 Days        2016         128           3  0.00001
# 0  Readmission in 30 Days        2017         128           3  0.00001
# 0  Readmission in 30 Days        2018         256           3  0.00001
# 0  Readmission in 30 Days        2019         256           3  0.00001
# 0  Readmission in 30 Days        2020         256           3  0.00001
# 0  Readmission in 30 Days        2021         128           3  0.00001
# 0  Readmission in 30 Days       10-13         256           3  0.00001
# 0  Readmission in 30 Days       11-14         256           3  0.00001
# 0  Readmission in 30 Days       12-15         256           3  0.00001
# 0  Readmission in 30 Days       13-16         256           3  0.00001
# 0  Readmission in 30 Days       14-17         128           3  0.00001
# 0  Readmission in 30 Days       15-18         256           3  0.00001
# 0  Readmission in 30 Days       09-13         256           1  0.00001
# 0  Readmission in 30 Days       09-14         128           1  0.00001
# 0  Readmission in 30 Days       09-15         256           3  0.00001
# 0  Readmission in 30 Days       09-16         256           3  0.00001
# 0  Readmission in 30 Days       09-17         256           3  0.00001
# 0  Readmission in 30 Days       09-18         256           3  0.00001
# 0           ICU Admission       09-12         256           1  0.00001
# 0           ICU Admission        2013         128           1  0.00010
# 0           ICU Admission        2014         128           1  0.00001
# 0           ICU Admission        2015         256           3  0.00001
# 0           ICU Admission        2016         256           1  0.00010
# 0           ICU Admission        2017         256           1  0.00001
# 0           ICU Admission        2018         256           1  0.00001
# 0           ICU Admission        2019         256           1  0.00001
# 0           ICU Admission        2020         128           1  0.00001
# 0           ICU Admission        2021         128           1  0.00001
# 0           ICU Admission       10-13         256           1  0.00001
# 0           ICU Admission       11-14         128           1  0.00001
# 0           ICU Admission       12-15         128           1  0.00001
# 0           ICU Admission       13-16         256           1  0.00001
# 0           ICU Admission       14-17         256           1  0.00001
# 0           ICU Admission       15-18         256           1  0.00001
# 0           ICU Admission       09-13         256           1  0.00001
# 0           ICU Admission       09-14         128           1  0.00001
# 0           ICU Admission       09-15         128           1  0.00001
# 0           ICU Admission       09-16         128           1  0.00001
# 0           ICU Admission       09-17         128           1  0.00001
# 0           ICU Admission       09-18         256           1  0.00001
#
#    drop_prob
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.50
# 0       0.50
# 0       0.75
# 0       0.50
# 0       0.75
# 0       0.50
# 0       0.75
# 0       0.50
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.75
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.75
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.75
# 0       0.75
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.00
# 0       0.00
# 0       0.25
# 0       0.00
# 0       0.25
# 0       0.25
# 0       0.50
# 0       0.75
# 0       0.50
# 0       0.50
# 0       0.00
# 0       0.25
# 0       0.50
# 0       0.00
# 0       0.00
# 0       0.00
# 0       0.25
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
# 0       0.50
