# %%
import os
import joblib
import pickle

import pandas as pd
import numpy as np

from utils_visualize import (
    get_result_table,
    plot_heatmap
)

pd.options.display.max_rows = 100

# %%
artifacts_fpath = '/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/clmbr/experiments/baseline/artifacts'

# %% [markdown]
# ## MODEL PERFORMANCE AND ROBUSTNESS

# %%
cmap = 'viridis'

y_axis = {
    'auc':{
        'lim':[-0.15, 0],
        'lim_raw':[0.75,.85],
        'label':'AUROC'
    },
    'auprc':{
        'lim':[-0.15, 0],
        'lim_raw':[.15,.35],
        'label':'AUPRC'
    },
    'ace_abs_logistic_logit':{
        'lim':[0, 0.10],
        'lim_raw':[0,0.05],
        'label':'Calibration'
    },
    'loss_bce':{
        'lim':[0, 0.4],
        'label':'BCE Loss'
    }
}

metrics = {
    'auc':'AUROC',
    'auprc':'AUPRC',
    'ace_abs_logistic_logit':'Calibration',
}

tasks = {
    'hospital_mortality':'In-Hospital Mortality',
    'LOS_7':'LOS > 7 Days',
    'readmission_30':'Readmission in 30 Days',
    'icu_admission':'Admission to ICU'
}

models = {
    'lr':'Logistic Regression',
    'gbm':'LightGBM'
}

train_years = {
    '2018':'18-18',
    '2017_2018':'17-18',
    '2016_2017_2018':'16-18',
    '2015_2016_2017_2018':'15-18',
    '2014_2015_2016_2017_2018':'14-18',
    '2013_2014_2015_2016_2017_2018':'13-18',
    '2012_2013_2014_2015_2016_2017_2018':'12-18',
    '2011_2012_2013_2014_2015_2016_2017_2018':'11-18',
    '2010_2011_2012_2013_2014_2015_2016_2017_2018':'10-18',
}

# %% [markdown]
# #### ID Performance

# %%
df = get_result_table(artifacts_fpath,train_years,tasks,metrics,models)
print("ID Performance of LR Models Trained on Various Year Groups With Increasing Sample Size and Diversity")
display(df[[v for k,v in train_years.items()]])
# Out:
# ID Performance of LR Models Trained on Various Year Groups With Increasing Sample Size and Diversity
# Train Group                                        18-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.923 (0.885, 0.952)
#                        AUPRC        0.363 (0.261, 0.495)
#                        Calibration  0.007 (0.003, 0.011)
# LOS > 7 Days           AUROC        0.838 (0.821, 0.854)
#                        AUPRC         0.538 (0.49, 0.582)
#                        Calibration  0.007 (0.001, 0.018)
# Readmission in 30 Days AUROC        0.778 (0.733, 0.815)
#                        AUPRC        0.252 (0.186, 0.327)
#                        Calibration  0.008 (0.002, 0.014)
# Admission to ICU       AUROC        0.844 (0.805, 0.883)
#                        AUPRC         0.26 (0.178, 0.343)
#                        Calibration   0.005 (0.001, 0.01)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.913 (0.879, 0.941)
#                        AUPRC        0.344 (0.229, 0.463)
#                        Calibration  0.013 (0.009, 0.018)
# LOS > 7 Days           AUROC        0.852 (0.835, 0.867)
#                        AUPRC        0.569 (0.524, 0.608)
#                        Calibration  0.013 (0.005, 0.021)
# Readmission in 30 Days AUROC        0.792 (0.755, 0.826)
#                        AUPRC         0.28 (0.208, 0.356)
#                        Calibration  0.007 (0.002, 0.013)
# Admission to ICU       AUROC         0.866 (0.83, 0.897)
#                        AUPRC          0.3 (0.206, 0.391)
#                        Calibration  0.012 (0.006, 0.017)
#
# Train Group                                        17-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.93 (0.908, 0.948)
#                        AUPRC         0.343 (0.262, 0.43)
#                        Calibration  0.004 (0.002, 0.007)
# LOS > 7 Days           AUROC        0.846 (0.833, 0.858)
#                        AUPRC        0.549 (0.515, 0.581)
#                        Calibration   0.004 (0.001, 0.01)
# Readmission in 30 Days AUROC        0.784 (0.757, 0.813)
#                        AUPRC        0.249 (0.197, 0.298)
#                        Calibration   0.006 (0.003, 0.01)
# Admission to ICU       AUROC        0.872 (0.843, 0.896)
#                        AUPRC         0.304 (0.23, 0.374)
#                        Calibration  0.004 (0.001, 0.007)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.933 (0.911, 0.952)
#                        AUPRC        0.343 (0.253, 0.428)
#                        Calibration  0.009 (0.006, 0.012)
# LOS > 7 Days           AUROC        0.862 (0.851, 0.873)
#                        AUPRC         0.592 (0.56, 0.626)
#                        Calibration  0.015 (0.008, 0.023)
# Readmission in 30 Days AUROC        0.815 (0.786, 0.841)
#                        AUPRC         0.29 (0.233, 0.345)
#                        Calibration  0.004 (0.001, 0.008)
# Admission to ICU       AUROC         0.889 (0.863, 0.91)
#                        AUPRC        0.358 (0.286, 0.425)
#                        Calibration  0.009 (0.005, 0.013)
#
# Train Group                                        16-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC           0.92 (0.9, 0.936)
#                        AUPRC        0.319 (0.252, 0.392)
#                        Calibration  0.004 (0.002, 0.006)
# LOS > 7 Days           AUROC        0.852 (0.843, 0.861)
#                        AUPRC        0.563 (0.538, 0.589)
#                        Calibration  0.004 (0.001, 0.008)
# Readmission in 30 Days AUROC        0.801 (0.779, 0.822)
#                        AUPRC         0.24 (0.196, 0.283)
#                        Calibration  0.005 (0.002, 0.008)
# Admission to ICU       AUROC        0.884 (0.863, 0.903)
#                        AUPRC        0.297 (0.233, 0.362)
#                        Calibration  0.003 (0.001, 0.005)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.926 (0.907, 0.943)
#                        AUPRC        0.351 (0.282, 0.426)
#                        Calibration  0.008 (0.006, 0.011)
# LOS > 7 Days           AUROC        0.868 (0.859, 0.878)
#                        AUPRC        0.608 (0.582, 0.633)
#                        Calibration  0.007 (0.002, 0.012)
# Readmission in 30 Days AUROC         0.818 (0.795, 0.84)
#                        AUPRC        0.268 (0.224, 0.318)
#                        Calibration  0.002 (0.001, 0.005)
# Admission to ICU       AUROC        0.901 (0.882, 0.918)
#                        AUPRC         0.33 (0.267, 0.389)
#                        Calibration  0.006 (0.003, 0.009)
#
# Train Group                                        15-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.915 (0.899, 0.93)
#                        AUPRC        0.281 (0.227, 0.344)
#                        Calibration  0.003 (0.001, 0.005)
# LOS > 7 Days           AUROC         0.851 (0.842, 0.86)
#                        AUPRC        0.561 (0.539, 0.583)
#                        Calibration  0.003 (0.001, 0.007)
# Readmission in 30 Days AUROC        0.806 (0.786, 0.824)
#                        AUPRC        0.238 (0.203, 0.276)
#                        Calibration  0.004 (0.001, 0.007)
# Admission to ICU       AUROC        0.897 (0.879, 0.912)
#                        AUPRC        0.297 (0.245, 0.359)
#                        Calibration  0.004 (0.001, 0.006)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.925 (0.909, 0.938)
#                        AUPRC         0.328 (0.267, 0.39)
#                        Calibration   0.008 (0.006, 0.01)
# LOS > 7 Days           AUROC        0.868 (0.861, 0.875)
#                        AUPRC        0.605 (0.584, 0.625)
#                        Calibration  0.012 (0.007, 0.017)
# Readmission in 30 Days AUROC        0.825 (0.805, 0.842)
#                        AUPRC        0.264 (0.226, 0.306)
#                        Calibration  0.003 (0.001, 0.006)
# Admission to ICU       AUROC        0.909 (0.894, 0.923)
#                        AUPRC        0.337 (0.282, 0.394)
#                        Calibration  0.006 (0.004, 0.008)
#
# Train Group                                        14-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.916 (0.901, 0.93)
#                        AUPRC          0.27 (0.22, 0.328)
#                        Calibration  0.002 (0.001, 0.004)
# LOS > 7 Days           AUROC        0.851 (0.843, 0.858)
#                        AUPRC        0.559 (0.539, 0.579)
#                        Calibration  0.003 (0.001, 0.007)
# Readmission in 30 Days AUROC        0.795 (0.776, 0.813)
#                        AUPRC        0.233 (0.202, 0.269)
#                        Calibration  0.003 (0.001, 0.005)
# Admission to ICU       AUROC        0.889 (0.872, 0.904)
#                        AUPRC        0.272 (0.225, 0.318)
#                        Calibration  0.002 (0.001, 0.004)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.924 (0.911, 0.937)
#                        AUPRC         0.295 (0.246, 0.35)
#                        Calibration  0.007 (0.006, 0.009)
# LOS > 7 Days           AUROC         0.868 (0.86, 0.875)
#                        AUPRC         0.61 (0.591, 0.629)
#                        Calibration  0.009 (0.006, 0.014)
# Readmission in 30 Days AUROC        0.821 (0.805, 0.836)
#                        AUPRC        0.277 (0.242, 0.314)
#                        Calibration  0.002 (0.001, 0.005)
# Admission to ICU       AUROC        0.904 (0.889, 0.916)
#                        AUPRC        0.318 (0.266, 0.363)
#                        Calibration  0.005 (0.003, 0.007)
#
# Train Group                                        13-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.917 (0.903, 0.93)
#                        AUPRC        0.282 (0.237, 0.329)
#                        Calibration  0.002 (0.001, 0.004)
# LOS > 7 Days           AUROC        0.849 (0.842, 0.856)
#                        AUPRC        0.565 (0.545, 0.584)
#                        Calibration    0.002 (0.0, 0.006)
# Readmission in 30 Days AUROC        0.792 (0.775, 0.808)
#                        AUPRC        0.233 (0.204, 0.264)
#                        Calibration  0.003 (0.001, 0.005)
# Admission to ICU       AUROC         0.89 (0.874, 0.904)
#                        AUPRC        0.279 (0.238, 0.326)
#                        Calibration  0.003 (0.001, 0.004)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.927 (0.916, 0.938)
#                        AUPRC        0.315 (0.264, 0.366)
#                        Calibration  0.006 (0.005, 0.008)
# LOS > 7 Days           AUROC        0.865 (0.858, 0.872)
#                        AUPRC        0.609 (0.591, 0.626)
#                        Calibration  0.005 (0.002, 0.009)
# Readmission in 30 Days AUROC        0.817 (0.801, 0.832)
#                        AUPRC        0.276 (0.241, 0.312)
#                        Calibration  0.003 (0.001, 0.005)
# Admission to ICU       AUROC        0.905 (0.891, 0.917)
#                        AUPRC        0.313 (0.269, 0.362)
#                        Calibration  0.004 (0.003, 0.006)
#
# Train Group                                        12-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.917 (0.902, 0.93)
#                        AUPRC        0.287 (0.242, 0.334)
#                        Calibration    0.001 (0.0, 0.003)
# LOS > 7 Days           AUROC         0.848 (0.84, 0.854)
#                        AUPRC        0.563 (0.547, 0.581)
#                        Calibration    0.002 (0.0, 0.006)
# Readmission in 30 Days AUROC        0.792 (0.777, 0.808)
#                        AUPRC          0.24 (0.212, 0.27)
#                        Calibration  0.003 (0.001, 0.005)
# Admission to ICU       AUROC         0.89 (0.876, 0.904)
#                        AUPRC         0.27 (0.229, 0.314)
#                        Calibration  0.003 (0.001, 0.005)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC         0.922 (0.91, 0.934)
#                        AUPRC        0.293 (0.249, 0.341)
#                        Calibration  0.006 (0.004, 0.007)
# LOS > 7 Days           AUROC         0.866 (0.86, 0.873)
#                        AUPRC        0.614 (0.597, 0.631)
#                        Calibration  0.011 (0.007, 0.015)
# Readmission in 30 Days AUROC        0.816 (0.801, 0.829)
#                        AUPRC        0.277 (0.248, 0.309)
#                        Calibration  0.002 (0.001, 0.005)
# Admission to ICU       AUROC        0.904 (0.891, 0.915)
#                        AUPRC        0.317 (0.275, 0.362)
#                        Calibration  0.005 (0.004, 0.007)
#
# Train Group                                        11-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.919 (0.906, 0.929)
#                        AUPRC        0.284 (0.248, 0.325)
#                        Calibration    0.001 (0.0, 0.003)
# LOS > 7 Days           AUROC        0.846 (0.839, 0.852)
#                        AUPRC         0.563 (0.547, 0.58)
#                        Calibration  0.002 (0.001, 0.005)
# Readmission in 30 Days AUROC        0.792 (0.778, 0.806)
#                        AUPRC         0.24 (0.213, 0.267)
#                        Calibration  0.003 (0.001, 0.005)
# Admission to ICU       AUROC         0.89 (0.877, 0.903)
#                        AUPRC         0.264 (0.23, 0.301)
#                        Calibration  0.003 (0.001, 0.004)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.922 (0.911, 0.932)
#                        AUPRC        0.297 (0.255, 0.343)
#                        Calibration  0.005 (0.004, 0.006)
# LOS > 7 Days           AUROC        0.863 (0.858, 0.869)
#                        AUPRC        0.608 (0.593, 0.623)
#                        Calibration   0.01 (0.006, 0.013)
# Readmission in 30 Days AUROC        0.813 (0.799, 0.826)
#                        AUPRC        0.271 (0.242, 0.301)
#                        Calibration    0.002 (0.0, 0.004)
# Admission to ICU       AUROC        0.904 (0.892, 0.916)
#                        AUPRC        0.316 (0.276, 0.356)
#                        Calibration  0.004 (0.003, 0.006)
#
# Train Group                                        10-18
# Model                                Logistic Regression              LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.918 (0.906, 0.929)   0.922 (0.91, 0.932)
#                        AUPRC        0.291 (0.253, 0.331)  0.299 (0.259, 0.341)
#                        Calibration    0.002 (0.0, 0.003)  0.005 (0.004, 0.006)
# LOS > 7 Days           AUROC         0.843 (0.837, 0.85)  0.863 (0.857, 0.869)
#                        AUPRC        0.561 (0.545, 0.576)   0.61 (0.596, 0.624)
#                        Calibration    0.002 (0.0, 0.006)  0.009 (0.006, 0.012)
# Readmission in 30 Days AUROC        0.795 (0.781, 0.808)    0.813 (0.8, 0.826)
#                        AUPRC         0.246 (0.221, 0.27)  0.273 (0.247, 0.299)
#                        Calibration  0.003 (0.001, 0.005)  0.003 (0.001, 0.005)
# Admission to ICU       AUROC        0.889 (0.875, 0.902)  0.901 (0.889, 0.913)
#                        AUPRC          0.263 (0.227, 0.3)  0.313 (0.277, 0.354)
#                        Calibration  0.003 (0.001, 0.004)  0.004 (0.003, 0.006)

# %% [markdown]
# #### Heat Map OOD Performance in 2019, 2020, and 2021

# %%
tasks = {
    'LOS_7':'LOS > 7 Days',
    'icu_admission':'Admission to ICU'
}

plot_heatmap(
    artifacts_fpath=artifacts_fpath,
    train_years=train_years,
    tasks=tasks,
    models=models,
    y_axis='auto',
    dv='comparator',
    figsize=(13,5)
)
