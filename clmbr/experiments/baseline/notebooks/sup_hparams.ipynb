# %%
import os
import yaml

import numpy as np
import pandas as pd

pd.options.display.max_rows = 100

# %%
artifacts_fpath = "/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/clmbr/experiments/baseline/artifacts"
hparams_fpath = "/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/clmbr/experiments/baseline/hyperparams/"

tasks = {
    'hospital_mortality':'In-Hospital Mortality',
    'LOS_7':'LOS > 7 Days',
    'readmission_30':'Readmission in 30 Days',
    'icu_admission':'ICU Admission'
}

models = {
    'lr':'Logistic Regression',
    'gbm':'LightGBM'
}

years = {
    '2009_2010_2011_2012':'09-12',
    '2013':'2013',
    '2014':'2014',
    '2015':'2015',
    '2016':'2016',
    '2017':'2017',
    '2018':'2018',
    '2019':'2019',
    '2020':'2020',
    '2021':'2021',
    '2009_2010_2011_2012':'09-12',
    '2010_2011_2012_2013':'10-13',
    '2011_2012_2013_2014':'11-14',
    '2012_2013_2014_2015':'12-15',
    '2013_2014_2015_2016':'13-16',
    '2014_2015_2016_2017':'14-17',
    '2015_2016_2017_2018':'15-18',
    '2009_2010_2011_2012':'09-12',
}

# %% [markdown]
# #### Hparam Grid

# %%
df_hparams=pd.DataFrame()
for model in models:
    
    hparams = yaml.load(
        open(f"{hparams_fpath}{model}.yml"),
        Loader=yaml.FullLoader
    )
    
    df = pd.DataFrame({
        k:[','.join([str(x) for x in v])] for k,v in hparams.items()
    })
    
    df = df.T
    df.columns=['Values']
    df['Model']=models[model]
    df_hparams=pd.concat((df_hparams,df))

# %%
df_hparams
# Out:
#                                                        Values  \
# C                  1e-06,1e-05,0.0001,0.001,0.01,0.1,1,10,100
# max_iter                                                10000
# learning_rate                                    0.1,0.2,0.01
# num_leaves                                            100,300
# n_estimators                                             1000
# max_depth                                                  -1
# boosting_type                                  gbdt,dart,goss
# objective                                              binary
# metric                                         binary_logloss
# first_metric_only                                        True
#
#                                  Model
# C                  Logistic Regression
# max_iter           Logistic Regression
# learning_rate                 LightGBM
# num_leaves                    LightGBM
# n_estimators                  LightGBM
# max_depth                     LightGBM
# boosting_type                 LightGBM
# objective                     LightGBM
# metric                        LightGBM
# first_metric_only             LightGBM

# %% [markdown]
# #### Selected hparams

# %%
for model in models:
    df_hparams = pd.DataFrame()
    for task in tasks:
        for year in years:

            fpath = os.path.join(
                artifacts_fpath,
                task,
                f"models/{model}_{year}"
            )

            best_model_name = [x for x in os.listdir(fpath) if "best_model" in x][0]

            hparams = yaml.load(
                open(f"{fpath}/{best_model_name}/hparams.yml"),
                Loader=yaml.FullLoader
            )

            df_hparams = pd.concat((
                df_hparams,
                pd.DataFrame({k:[v] for k,v in hparams.items()}).assign(
                    Task=tasks[task],
                    Train_Group=years[year]
                )
            ))
            
    display(df_hparams)
# Out:
#        C  max_iter                    Task Train_Group
# 0  0.010     10000   In-Hospital Mortality       09-12
# 0  0.010     10000   In-Hospital Mortality        2013
# 0  0.010     10000   In-Hospital Mortality        2014
# 0  0.010     10000   In-Hospital Mortality        2015
# 0  0.010     10000   In-Hospital Mortality        2016
# 0  0.010     10000   In-Hospital Mortality        2017
# 0  0.010     10000   In-Hospital Mortality        2018
# 0  0.010     10000   In-Hospital Mortality        2019
# 0  0.010     10000   In-Hospital Mortality        2020
# 0  0.010     10000   In-Hospital Mortality        2021
# 0  0.010     10000   In-Hospital Mortality       10-13
# 0  0.010     10000   In-Hospital Mortality       11-14
# 0  0.010     10000   In-Hospital Mortality       12-15
# 0  0.010     10000   In-Hospital Mortality       13-16
# 0  0.010     10000   In-Hospital Mortality       14-17
# 0  0.010     10000   In-Hospital Mortality       15-18
# 0  0.010     10000            LOS > 7 Days       09-12
# 0  0.010     10000            LOS > 7 Days        2013
# 0  0.010     10000            LOS > 7 Days        2014
# 0  0.010     10000            LOS > 7 Days        2015
# 0  0.010     10000            LOS > 7 Days        2016
# 0  0.010     10000            LOS > 7 Days        2017
# 0  0.010     10000            LOS > 7 Days        2018
# 0  0.010     10000            LOS > 7 Days        2019
# 0  0.010     10000            LOS > 7 Days        2020
# 0  0.010     10000            LOS > 7 Days        2021
# 0  0.010     10000            LOS > 7 Days       10-13
# 0  0.010     10000            LOS > 7 Days       11-14
# 0  0.010     10000            LOS > 7 Days       12-15
# 0  0.010     10000            LOS > 7 Days       13-16
# 0  0.010     10000            LOS > 7 Days       14-17
# 0  0.010     10000            LOS > 7 Days       15-18
# 0  0.001     10000  Readmission in 30 Days       09-12
# 0  0.001     10000  Readmission in 30 Days        2013
# 0  0.001     10000  Readmission in 30 Days        2014
# 0  0.010     10000  Readmission in 30 Days        2015
# 0  0.001     10000  Readmission in 30 Days        2016
# 0  0.010     10000  Readmission in 30 Days        2017
# 0  0.010     10000  Readmission in 30 Days        2018
# 0  0.001     10000  Readmission in 30 Days        2019
# 0  0.001     10000  Readmission in 30 Days        2020
# 0  0.001     10000  Readmission in 30 Days        2021
# 0  0.001     10000  Readmission in 30 Days       10-13
# 0  0.001     10000  Readmission in 30 Days       11-14
# 0  0.001     10000  Readmission in 30 Days       12-15
# 0  0.001     10000  Readmission in 30 Days       13-16
# 0  0.001     10000  Readmission in 30 Days       14-17
# 0  0.001     10000  Readmission in 30 Days       15-18
# 0  0.010     10000           ICU Admission       09-12
# 0  0.100     10000           ICU Admission        2013
# 0  0.010     10000           ICU Admission        2014
# 0  0.010     10000           ICU Admission        2015
# 0  0.010     10000           ICU Admission        2016
# 0  0.100     10000           ICU Admission        2017
# 0  0.010     10000           ICU Admission        2018
# 0  0.010     10000           ICU Admission        2019
# 0  0.010     10000           ICU Admission        2020
# 0  0.010     10000           ICU Admission        2021
# 0  0.010     10000           ICU Admission       10-13
# 0  0.010     10000           ICU Admission       11-14
# 0  0.010     10000           ICU Admission       12-15
# 0  0.010     10000           ICU Admission       13-16
# 0  0.010     10000           ICU Admission       14-17
# 0  0.010     10000           ICU Admission       15-18
#   boosting_type  first_metric_only  learning_rate  max_depth          metric  \
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.10         -1  binary_logloss
# 0          goss               True           0.10         -1  binary_logloss
# 0          goss               True           0.20         -1  binary_logloss
# 0          goss               True           0.10         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          dart               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          gbdt               True           0.01         -1  binary_logloss
# 0          goss               True           0.10         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
# 0          goss               True           0.01         -1  binary_logloss
#
#    n_estimators  num_leaves objective                    Task Train_Group
# 0           323         100    binary   In-Hospital Mortality       09-12
# 0           226         300    binary   In-Hospital Mortality        2013
# 0            21         100    binary   In-Hospital Mortality        2014
# 0            20         100    binary   In-Hospital Mortality        2015
# 0             9         300    binary   In-Hospital Mortality        2016
# 0            21         100    binary   In-Hospital Mortality        2017
# 0           242         300    binary   In-Hospital Mortality        2018
# 0           157         100    binary   In-Hospital Mortality        2019
# 0           205         300    binary   In-Hospital Mortality        2020
# 0           233         300    binary   In-Hospital Mortality        2021
# 0           324         100    binary   In-Hospital Mortality       10-13
# 0           347         100    binary   In-Hospital Mortality       11-14
# 0           351         100    binary   In-Hospital Mortality       12-15
# 0           345         100    binary   In-Hospital Mortality       13-16
# 0           367         100    binary   In-Hospital Mortality       14-17
# 0           354         100    binary   In-Hospital Mortality       15-18
# 0           658         100    binary            LOS > 7 Days       09-12
# 0           448         300    binary            LOS > 7 Days        2013
# 0           357         100    binary            LOS > 7 Days        2014
# 0           546         100    binary            LOS > 7 Days        2015
# 0           512         100    binary            LOS > 7 Days        2016
# 0           329         100    binary            LOS > 7 Days        2017
# 0           405         100    binary            LOS > 7 Days        2018
# 0           436         100    binary            LOS > 7 Days        2019
# 0           548         100    binary            LOS > 7 Days        2020
# 0           309         100    binary            LOS > 7 Days        2021
# 0           669         100    binary            LOS > 7 Days       10-13
# 0           618         100    binary            LOS > 7 Days       11-14
# 0           473         300    binary            LOS > 7 Days       12-15
# 0           504         300    binary            LOS > 7 Days       13-16
# 0           493         300    binary            LOS > 7 Days       14-17
# 0           518         300    binary            LOS > 7 Days       15-18
# 0           398         100    binary  Readmission in 30 Days       09-12
# 0           140         300    binary  Readmission in 30 Days        2013
# 0           186         100    binary  Readmission in 30 Days        2014
# 0           170         100    binary  Readmission in 30 Days        2015
# 0           194         100    binary  Readmission in 30 Days        2016
# 0           168         300    binary  Readmission in 30 Days        2017
# 0           203         100    binary  Readmission in 30 Days        2018
# 0           241         100    binary  Readmission in 30 Days        2019
# 0           270         100    binary  Readmission in 30 Days        2020
# 0          1000         300    binary  Readmission in 30 Days        2021
# 0           343         100    binary  Readmission in 30 Days       10-13
# 0           291         100    binary  Readmission in 30 Days       11-14
# 0           289         100    binary  Readmission in 30 Days       12-15
# 0           324         100    binary  Readmission in 30 Days       13-16
# 0           281         100    binary  Readmission in 30 Days       14-17
# 0           283         100    binary  Readmission in 30 Days       15-18
# 0           371         100    binary           ICU Admission       09-12
# 0            25         100    binary           ICU Admission        2013
# 0           204         100    binary           ICU Admission        2014
# 0           191         300    binary           ICU Admission        2015
# 0           227         100    binary           ICU Admission        2016
# 0           217         300    binary           ICU Admission        2017
# 0           233         100    binary           ICU Admission        2018
# 0           223         100    binary           ICU Admission        2019
# 0           318         100    binary           ICU Admission        2020
# 0           225         100    binary           ICU Admission        2021
# 0           360         100    binary           ICU Admission       10-13
# 0           377         100    binary           ICU Admission       11-14
# 0           359         100    binary           ICU Admission       12-15
# 0           352         100    binary           ICU Admission       13-16
# 0           347         100    binary           ICU Admission       14-17
# 0           367         100    binary           ICU Admission       15-18
