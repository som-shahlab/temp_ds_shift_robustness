# %%
import os
import joblib
import pickle

import pandas as pd
import numpy as np

from utils_visualize import (
    get_result_table,
    plot_heatmap
)

pd.options.display.max_rows = 100

# %%
artifacts_fpath = '/local-scratch/nigam/projects/lguo/temp_ds_shift_robustness/clmbr/experiments/baseline/artifacts'

# %% [markdown]
# #### Setup table and figure parameters

# %%
y_axis = {
    'auc':{
        'lim':[-0.18, 0.18],
        'lim_raw':[0.65,1],
        'label':'AUROC'
    },
    'auprc':{
        'lim':[-0.25, 0.25],
        'lim_raw':[0,.75],
        'label':'AUPRC'
    },
    'ace_abs_logistic_logit':{
        'lim':[-0.01, 0.06],
        'lim_raw':[0,0.08],
        'label':'Calibration'
    },
    'loss_bce':{
        'lim':[0, 0.2],
        'label':'BCE Loss'
    }
}

metrics = {
    'auc':'AUROC',
    'auprc':'AUPRC',
    'ace_abs_logistic_logit':'Calibration',
}

models = {
    'lr':'Logistic Regression',
    'gbm':'LightGBM'
}

tasks = {
    'hospital_mortality':'In-Hospital Mortality',
    'LOS_7':'LOS > 7 Days',
    'readmission_30':'Readmission in 30 Days',
    'icu_admission':'Admission to ICU'
}

train_years = {
    '2009_2010_2011_2012':'09-12',
    '2010_2011_2012_2013':'10-13',
    '2011_2012_2013_2014':'11-14',
    '2012_2013_2014_2015':'12-15',
    '2013_2014_2015_2016':'13-16',
    '2014_2015_2016_2017':'14-17',
    '2015_2016_2017_2018':'15-18',
    '2016_2017_2018_2019':'16-19',
    '2017_2018_2019_2020':'17-20',
    '2018_2019_2020_2021':'18-21',
}

# %% [markdown]
# #### ID Performance

# %%
df = get_result_table(artifacts_fpath,train_years,tasks,metrics,models)
print("ID Performance of LR Models Trained on Various Year Groups")
display(df)
# Out:
# ID Performance of LR Models Trained on Various Year Groups
# Train Group                                        09-12  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.897 (0.875, 0.916)
#                        AUPRC         0.23 (0.179, 0.286)
#                        Calibration    0.002 (0.0, 0.004)
# LOS > 7 Days           AUROC        0.825 (0.814, 0.836)
#                        AUPRC        0.549 (0.525, 0.576)
#                        Calibration  0.004 (0.001, 0.009)
# Readmission in 30 Days AUROC        0.789 (0.767, 0.812)
#                        AUPRC        0.273 (0.233, 0.314)
#                        Calibration  0.008 (0.004, 0.012)
# Admission to ICU       AUROC        0.871 (0.842, 0.897)
#                        AUPRC        0.219 (0.157, 0.283)
#                        Calibration  0.004 (0.001, 0.006)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.904 (0.883, 0.923)
#                        AUPRC        0.236 (0.183, 0.295)
#                        Calibration  0.005 (0.003, 0.008)
# LOS > 7 Days           AUROC        0.845 (0.835, 0.855)
#                        AUPRC        0.591 (0.567, 0.615)
#                        Calibration   0.01 (0.004, 0.015)
# Readmission in 30 Days AUROC        0.794 (0.773, 0.813)
#                        AUPRC         0.265 (0.23, 0.304)
#                        Calibration  0.008 (0.004, 0.013)
# Admission to ICU       AUROC        0.869 (0.837, 0.896)
#                        AUPRC        0.252 (0.187, 0.318)
#                        Calibration   0.007 (0.004, 0.01)
#
# Train Group                                        10-13  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.903 (0.883, 0.921)
#                        AUPRC         0.285 (0.23, 0.352)
#                        Calibration    0.002 (0.0, 0.004)
# LOS > 7 Days           AUROC        0.826 (0.817, 0.837)
#                        AUPRC        0.551 (0.523, 0.577)
#                        Calibration  0.004 (0.001, 0.009)
# Readmission in 30 Days AUROC        0.783 (0.759, 0.804)
#                        AUPRC          0.261 (0.221, 0.3)
#                        Calibration  0.007 (0.004, 0.011)
# Admission to ICU       AUROC        0.878 (0.855, 0.901)
#                        AUPRC         0.23 (0.179, 0.283)
#                        Calibration  0.004 (0.002, 0.007)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.905 (0.883, 0.923)
#                        AUPRC        0.283 (0.225, 0.349)
#                        Calibration  0.006 (0.004, 0.009)
# LOS > 7 Days           AUROC        0.845 (0.835, 0.855)
#                        AUPRC        0.594 (0.568, 0.619)
#                        Calibration   0.01 (0.004, 0.016)
# Readmission in 30 Days AUROC        0.789 (0.767, 0.811)
#                        AUPRC          0.27 (0.23, 0.314)
#                        Calibration  0.007 (0.003, 0.012)
# Admission to ICU       AUROC        0.881 (0.859, 0.902)
#                        AUPRC        0.275 (0.218, 0.339)
#                        Calibration  0.006 (0.003, 0.009)
#
# Train Group                                        11-14  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.913 (0.895, 0.931)
#                        AUPRC         0.267 (0.21, 0.331)
#                        Calibration    0.002 (0.0, 0.004)
# LOS > 7 Days           AUROC        0.833 (0.823, 0.843)
#                        AUPRC        0.562 (0.538, 0.587)
#                        Calibration  0.004 (0.001, 0.009)
# Readmission in 30 Days AUROC        0.764 (0.739, 0.787)
#                        AUPRC        0.241 (0.204, 0.283)
#                        Calibration  0.004 (0.001, 0.008)
# Admission to ICU       AUROC         0.875 (0.85, 0.897)
#                        AUPRC        0.214 (0.168, 0.272)
#                        Calibration  0.003 (0.001, 0.006)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC         0.903 (0.881, 0.92)
#                        AUPRC        0.276 (0.216, 0.337)
#                        Calibration  0.005 (0.003, 0.008)
# LOS > 7 Days           AUROC          0.85 (0.84, 0.859)
#                        AUPRC        0.598 (0.574, 0.623)
#                        Calibration  0.012 (0.007, 0.018)
# Readmission in 30 Days AUROC        0.782 (0.758, 0.805)
#                        AUPRC        0.267 (0.228, 0.305)
#                        Calibration  0.005 (0.002, 0.008)
# Admission to ICU       AUROC        0.878 (0.855, 0.898)
#                        AUPRC        0.253 (0.195, 0.315)
#                        Calibration  0.005 (0.002, 0.008)
#
# Train Group                                        12-15  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.913 (0.893, 0.931)
#                        AUPRC        0.265 (0.209, 0.328)
#                        Calibration    0.001 (0.0, 0.003)
# LOS > 7 Days           AUROC          0.84 (0.831, 0.85)
#                        AUPRC        0.554 (0.528, 0.579)
#                        Calibration  0.004 (0.001, 0.009)
# Readmission in 30 Days AUROC        0.777 (0.754, 0.801)
#                        AUPRC        0.239 (0.201, 0.277)
#                        Calibration  0.004 (0.001, 0.007)
# Admission to ICU       AUROC        0.892 (0.871, 0.911)
#                        AUPRC        0.219 (0.175, 0.268)
#                        Calibration  0.004 (0.002, 0.007)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC         0.901 (0.883, 0.92)
#                        AUPRC        0.266 (0.208, 0.328)
#                        Calibration  0.005 (0.003, 0.008)
# LOS > 7 Days           AUROC        0.857 (0.848, 0.865)
#                        AUPRC        0.602 (0.577, 0.625)
#                        Calibration   0.015 (0.01, 0.021)
# Readmission in 30 Days AUROC        0.806 (0.784, 0.825)
#                        AUPRC        0.284 (0.243, 0.323)
#                        Calibration   0.007 (0.003, 0.01)
# Admission to ICU       AUROC        0.897 (0.879, 0.914)
#                        AUPRC        0.258 (0.204, 0.316)
#                        Calibration  0.006 (0.004, 0.009)
#
# Train Group                                        13-16  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.909 (0.89, 0.925)
#                        AUPRC        0.253 (0.198, 0.318)
#                        Calibration    0.002 (0.0, 0.004)
# LOS > 7 Days           AUROC        0.846 (0.836, 0.855)
#                        AUPRC        0.561 (0.536, 0.584)
#                        Calibration  0.004 (0.001, 0.008)
# Readmission in 30 Days AUROC        0.781 (0.758, 0.801)
#                        AUPRC        0.216 (0.182, 0.256)
#                        Calibration    0.002 (0.0, 0.005)
# Admission to ICU       AUROC        0.898 (0.878, 0.916)
#                        AUPRC        0.254 (0.202, 0.314)
#                        Calibration  0.004 (0.002, 0.007)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC         0.91 (0.893, 0.926)
#                        AUPRC        0.295 (0.237, 0.359)
#                        Calibration  0.007 (0.004, 0.009)
# LOS > 7 Days           AUROC        0.862 (0.854, 0.871)
#                        AUPRC        0.604 (0.582, 0.626)
#                        Calibration   0.015 (0.009, 0.02)
# Readmission in 30 Days AUROC          0.81 (0.79, 0.828)
#                        AUPRC           0.26 (0.221, 0.3)
#                        Calibration  0.003 (0.001, 0.007)
# Admission to ICU       AUROC         0.91 (0.893, 0.925)
#                        AUPRC        0.265 (0.212, 0.317)
#                        Calibration  0.004 (0.002, 0.007)
#
# Train Group                                        14-17  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.91 (0.893, 0.927)
#                        AUPRC        0.243 (0.188, 0.309)
#                        Calibration    0.002 (0.0, 0.004)
# LOS > 7 Days           AUROC         0.849 (0.84, 0.858)
#                        AUPRC        0.552 (0.526, 0.577)
#                        Calibration   0.005 (0.001, 0.01)
# Readmission in 30 Days AUROC        0.792 (0.772, 0.812)
#                        AUPRC        0.218 (0.182, 0.257)
#                        Calibration  0.003 (0.001, 0.006)
# Admission to ICU       AUROC        0.901 (0.883, 0.917)
#                        AUPRC         0.27 (0.213, 0.329)
#                        Calibration  0.003 (0.001, 0.005)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.919 (0.903, 0.932)
#                        AUPRC         0.29 (0.226, 0.352)
#                        Calibration  0.007 (0.004, 0.009)
# LOS > 7 Days           AUROC         0.868 (0.86, 0.876)
#                        AUPRC        0.604 (0.583, 0.625)
#                        Calibration   0.01 (0.005, 0.015)
# Readmission in 30 Days AUROC        0.819 (0.799, 0.839)
#                        AUPRC        0.254 (0.214, 0.299)
#                        Calibration  0.003 (0.001, 0.006)
# Admission to ICU       AUROC        0.912 (0.897, 0.926)
#                        AUPRC        0.319 (0.259, 0.374)
#                        Calibration  0.004 (0.002, 0.007)
#
# Train Group                                        15-18  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC         0.915 (0.899, 0.93)
#                        AUPRC        0.281 (0.227, 0.344)
#                        Calibration  0.003 (0.001, 0.005)
# LOS > 7 Days           AUROC         0.851 (0.842, 0.86)
#                        AUPRC        0.561 (0.539, 0.583)
#                        Calibration  0.003 (0.001, 0.007)
# Readmission in 30 Days AUROC        0.806 (0.786, 0.824)
#                        AUPRC        0.238 (0.203, 0.276)
#                        Calibration  0.004 (0.001, 0.007)
# Admission to ICU       AUROC        0.897 (0.879, 0.912)
#                        AUPRC        0.297 (0.245, 0.359)
#                        Calibration  0.004 (0.001, 0.006)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.925 (0.909, 0.938)
#                        AUPRC         0.328 (0.267, 0.39)
#                        Calibration   0.008 (0.006, 0.01)
# LOS > 7 Days           AUROC        0.868 (0.861, 0.875)
#                        AUPRC        0.605 (0.584, 0.625)
#                        Calibration  0.012 (0.007, 0.017)
# Readmission in 30 Days AUROC        0.825 (0.805, 0.842)
#                        AUPRC        0.264 (0.226, 0.306)
#                        Calibration  0.003 (0.001, 0.006)
# Admission to ICU       AUROC        0.909 (0.894, 0.923)
#                        AUPRC        0.337 (0.282, 0.394)
#                        Calibration  0.006 (0.004, 0.008)
#
# Train Group                                        16-19  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC          0.916 (0.9, 0.932)
#                        AUPRC        0.274 (0.217, 0.328)
#                        Calibration  0.003 (0.001, 0.005)
# LOS > 7 Days           AUROC         0.852 (0.844, 0.86)
#                        AUPRC        0.568 (0.546, 0.589)
#                        Calibration  0.003 (0.001, 0.007)
# Readmission in 30 Days AUROC        0.806 (0.786, 0.824)
#                        AUPRC        0.251 (0.214, 0.288)
#                        Calibration  0.005 (0.003, 0.008)
# Admission to ICU       AUROC         0.896 (0.881, 0.91)
#                        AUPRC         0.32 (0.272, 0.367)
#                        Calibration  0.004 (0.002, 0.007)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.918 (0.902, 0.935)
#                        AUPRC        0.285 (0.231, 0.345)
#                        Calibration  0.008 (0.006, 0.009)
# LOS > 7 Days           AUROC        0.867 (0.859, 0.874)
#                        AUPRC        0.609 (0.586, 0.629)
#                        Calibration  0.013 (0.008, 0.018)
# Readmission in 30 Days AUROC        0.824 (0.806, 0.841)
#                        AUPRC        0.288 (0.251, 0.328)
#                        Calibration  0.003 (0.001, 0.006)
# Admission to ICU       AUROC        0.901 (0.886, 0.916)
#                        AUPRC        0.355 (0.306, 0.405)
#                        Calibration   0.008 (0.005, 0.01)
#
# Train Group                                        17-20  \
# Model                                Logistic Regression
# Task                   Metric
# In-Hospital Mortality  AUROC        0.921 (0.906, 0.934)
#                        AUPRC        0.264 (0.215, 0.319)
#                        Calibration    0.001 (0.0, 0.003)
# LOS > 7 Days           AUROC         0.848 (0.84, 0.856)
#                        AUPRC        0.562 (0.542, 0.582)
#                        Calibration  0.004 (0.001, 0.008)
# Readmission in 30 Days AUROC         0.809 (0.79, 0.825)
#                        AUPRC        0.237 (0.204, 0.274)
#                        Calibration  0.006 (0.003, 0.008)
# Admission to ICU       AUROC        0.894 (0.881, 0.908)
#                        AUPRC        0.348 (0.306, 0.393)
#                        Calibration  0.005 (0.002, 0.007)
#
# Train Group                                               \
# Model                                           LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.917 (0.901, 0.931)
#                        AUPRC        0.265 (0.212, 0.325)
#                        Calibration  0.005 (0.003, 0.007)
# LOS > 7 Days           AUROC        0.864 (0.856, 0.872)
#                        AUPRC        0.602 (0.579, 0.621)
#                        Calibration  0.012 (0.008, 0.016)
# Readmission in 30 Days AUROC         0.822 (0.805, 0.84)
#                        AUPRC          0.27 (0.236, 0.31)
#                        Calibration    0.002 (0.0, 0.005)
# Admission to ICU       AUROC         0.91 (0.898, 0.921)
#                        AUPRC        0.418 (0.374, 0.458)
#                        Calibration   0.008 (0.006, 0.01)
#
# Train Group                                        18-21
# Model                                Logistic Regression              LightGBM
# Task                   Metric
# In-Hospital Mortality  AUROC        0.918 (0.901, 0.932)  0.914 (0.897, 0.929)
#                        AUPRC         0.238 (0.192, 0.29)  0.232 (0.182, 0.286)
#                        Calibration    0.001 (0.0, 0.003)  0.005 (0.003, 0.007)
# LOS > 7 Days           AUROC        0.841 (0.833, 0.849)   0.858 (0.85, 0.866)
#                        AUPRC        0.553 (0.533, 0.573)  0.595 (0.574, 0.617)
#                        Calibration   0.006 (0.002, 0.01)  0.014 (0.009, 0.019)
# Readmission in 30 Days AUROC        0.801 (0.783, 0.821)  0.814 (0.794, 0.831)
#                        AUPRC         0.23 (0.198, 0.265)  0.272 (0.234, 0.309)
#                        Calibration  0.005 (0.002, 0.008)  0.003 (0.001, 0.006)
# Admission to ICU       AUROC          0.887 (0.874, 0.9)  0.906 (0.894, 0.917)
#                        AUPRC        0.354 (0.311, 0.395)  0.419 (0.375, 0.463)
#                        Calibration  0.005 (0.003, 0.008)  0.009 (0.006, 0.011)

# %% [markdown]
# #### Heatmap

# %%
tasks = {
    'LOS_7':'LOS > 7 Days',
    'icu_admission':'Admission to ICU'
}

train_years = {
    '2013':'13-13',
    '2014':'14-14',
    '2015':'15-15',
    '2016':'16-16',
    '2017':'17-17',
    '2018':'18-18',
    '2019':'19-19',
    '2020':'20-20',
    '2021':'21-21',
    '2010_2011_2012_2013':'10-13',
    '2011_2012_2013_2014':'11-14',
    '2012_2013_2014_2015':'12-15',
    '2013_2014_2015_2016':'13-16',
    '2014_2015_2016_2017':'14-17',
    '2015_2016_2017_2018':'15-18',
    '2016_2017_2018_2019':'16-19',
    '2017_2018_2019_2020':'17-20',
    '2018_2019_2020_2021':'18-21',
}

plot_heatmap(
    artifacts_fpath=artifacts_fpath,
    train_years=train_years,
    tasks=tasks,
    models=models,
    dv='comparator',
    y_axis='auto',
    test_group=['2013','2014','2015','2016','2017','2018','2019','2020','2021'],
    figsize=(18,8)
)
# Out:
# /local-scratch/nigam/envs/lguo/temp_ds_shift_robustness/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
